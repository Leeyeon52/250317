# %%
import pandas as pd
import numpy as np
adams_act = pd.DataFrame(
                [
                  [12, 92],
                  [13, 65],
                  [14, 96]
                ],
                   columns=['Date', 'Act'])
print(adams_act)
# Out:
#    Date  Act
# 0    12   92
# 1    13   65
# 2    14   96

# %%
adams_act.idxmin()
# Out:
# Date    0
# Act     1
# dtype: int64

# %%
adams_act.idxmin(axis=1)
# Out:
# 0    Date
# 1    Date
# 2    Date
# dtype: object

# %%
adams_act.idxmax()
# Out:
# Date    2
# Act     2
# dtype: int64

# %%
adams_act.cummin()
# Out:
#    Date  Act
# 0    12   92
# 1    12   65
# 2    12   65

# %%
adams_act.cummax()
# Out:
#    Date  Act
# 0    12   92
# 1    13   92
# 2    14   96

# %%
adams_act.cumsum()
# Out:
#    Date  Act
# 0    12   92
# 1    25  157
# 2    39  253

# %%
adams_act.cumprod()
# Out:
#    Date     Act
# 0    12      92
# 1   156    5980
# 2  2184  574080

# %%
adams_act.diff()
# Out:
#    Date   Act
# 0   NaN   NaN
# 1   1.0 -27.0
# 2   1.0  31.0

# %%
adams_act.pct_change()
# Out:
#        Date       Act
# 0       NaN       NaN
# 1  0.083333 -0.293478
# 2  0.076923  0.476923

# %%
adams_act.expanding().sum()
# Out:
#    Date    Act
# 0  12.0   92.0
# 1  25.0  157.0
# 2  39.0  253.0

# %%
adams_act.expanding().mean()
# Out:
#    Date        Act
# 0  12.0  92.000000
# 1  12.5  78.500000
# 2  13.0  84.333333

# %%
adams_act.expanding(min_periods=3).sum()
# Out:
#    Date    Act
# 0   NaN    NaN
# 1   NaN    NaN
# 2  39.0  253.0

# %%
adams_act.rolling(window=2).sum()
# Out:
#    Date    Act
# 0   NaN    NaN
# 1  25.0  157.0
# 2  27.0  161.0

# %%
adams_act.rolling(window=2).mean()
# Out:
#    Date   Act
# 0   NaN   NaN
# 1  12.5  78.5
# 2  13.5  80.5

# %%
adams_act.rolling(window=3).sum()
# Out:
#    Date    Act
# 0   NaN    NaN
# 1   NaN    NaN
# 2  39.0  253.0

# %%
adams_act.rolling(window=3).mean()
# Out:
#    Date        Act
# 0   NaN        NaN
# 1   NaN        NaN
# 2  13.0  84.333333
